# %% [markdown]
# # Google Drive Mount

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Install

# %%
# !pip install transformers

# %%
# !pip list | grep transformers
# Out:
# transformers                     4.35.2

# %% [markdown]
# # 3.4 Huggingface Hub 등록

# %% [markdown]
# ### push_to_hub()

# %%
import os
os.chdir('drive/MyDrive/Books')

import config as cfg
from transformers import AutoTokenizer, AutoModelForSequenceClassification

tokenizer = AutoTokenizer.from_pretrained('outputs/trained_model')
model = AutoModelForSequenceClassification.from_pretrained('outputs/trained_model')

REPO_NAME = cfg.MY_REPO_NAME # ex) 'Seonghwan/my-bert-fine-tuned-psh1'
AUTH_TOKEN = cfg.MY_OWN_TOKEN

# %%
model.push_to_hub(
    REPO_NAME,
    use_temp_dir=True,
    use_auth_token=AUTH_TOKEN
)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/utils/hub.py:853: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# model.safetensors:   0%|          | 0.00/443M [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/Seonghwan/my-bert-fine-tuned-psh1/commit/49b8ae8360e711fa425d3c842ebe264e9a9a26ba', commit_message='Upload BertForSequenceClassification', commit_description='', oid='49b8ae8360e711fa425d3c842ebe264e9a9a26ba', pr_url=None, pr_revision=None, pr_num=None)

# %%
tokenizer.push_to_hub(
    REPO_NAME,
    use_temp_dir=True,
    use_auth_token=AUTH_TOKEN
)
# Out:
# CommitInfo(commit_url='https://huggingface.co/Seonghwan/my-bert-fine-tuned-psh1/commit/66759ed6c3e013988dc96901be12389bbacb28cd', commit_message='Upload tokenizer', commit_description='', oid='66759ed6c3e013988dc96901be12389bbacb28cd', pr_url=None, pr_revision=None, pr_num=None)

# %% [markdown]
# #### 모델 불러오기

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification

# %%
tokenizer = AutoTokenizer.from_pretrained('Seonghwan/my-bert-fine-tuned-psh1')
model = AutoModelForSequenceClassification.from_pretrained('Seonghwan/my-bert-fine-tuned-psh1')
# Out:
# tokenizer_config.json:   0%|          | 0.00/1.34k [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/248k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/752k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/695 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.00k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/443M [00:00<?, ?B/s]

# %%
print(tokenizer)
print(model)
# Out:
# BertTokenizerFast(name_or_path='Seonghwan/my-bert-fine-tuned-psh1', vocab_size=32000, model_max_length=512, is_fast=True, padding_side='right', truncation_side='right', special_tokens={'unk_token': '[UNK]', 'sep_token': '[SEP]', 'pad_token': '[PAD]', 'cls_token': '[CLS]', 'mask_token': '[MASK]'}, clean_up_tokenization_spaces=True),  added_tokens_decoder={
# 	0: AddedToken("[PAD]", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	1: AddedToken("[UNK]", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	2: AddedToken("[CLS]", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	3: AddedToken("[SEP]", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	4: AddedToken("[MASK]", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# }
# BertForSequenceClassification(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
# ...

# %% [markdown]
# ### CLI

# %%
import os
os.chdir('drive/MyDrive/Books')

import config as cfg
from transformers import AutoTokenizer, AutoModelForSequenceClassification

tokenizer = AutoTokenizer.from_pretrained('outputs/trained_model')
model = AutoModelForSequenceClassification.from_pretrained('outputs/trained_model')

# %%
# !git lfs install
# Out:
# Git LFS initialized.

# %%
# !git config --global user.email {cfg.YOUR_EMAIL}
# !git config --global user.name {cfg.YOUR_NAME}

# %%
# !git config --list
# Out:
# filter.lfs.clean=git-lfs clean -- %f
# filter.lfs.smudge=git-lfs smudge -- %f
# filter.lfs.process=git-lfs filter-process
# filter.lfs.required=true
# filter.lfs.clean=git-lfs clean -- %f
# filter.lfs.smudge=git-lfs smudge -- %f
# filter.lfs.process=git-lfs filter-process
# filter.lfs.required=true
# user.email=hipster4020@gmail.com
# user.name=Seonghwan

# %%
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     A token is already saved on your machine. Run `huggingface-cli whoami` to get more information or `huggingface-cli logout` if you want to log out.
#     Setting a new token will erase the existing one.
#     To login, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Token:
# Add token as git credential? (Y/n) ㅛ
# ...

# %%
# !huggingface-cli repo create {cfg.MY_REPO_NAME2.split('/')[1]}
# Out:
# git version 2.34.1
# git-lfs/3.0.2 (GitHub; linux amd64; go 1.18.1)
#
# You are about to create Seonghwan/my-bert-fine-tuned-psh2
# Proceed? [Y/n] y
#
# Your repo now lives at:
#   https://huggingface.co/Seonghwan/my-bert-fine-tuned-psh2
#
# You can clone it locally with the command below, and commit/push as usual.
#
#   git clone https://huggingface.co/Seonghwan/my-bert-fine-tuned-psh2

# %%
# !git clone https://huggingface.co/{cfg.MY_REPO_NAME2}
# Out:
# Cloning into 'my-bert-fine-tuned-psh2'...
# remote: Enumerating objects: 3, done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 3
# Unpacking objects: 100% (3/3), 412 bytes | 17.00 KiB/s, done.

# %%
# !cp -r outputs/trained_model/* {cfg.MY_REPO_NAME2.split('/')[1]}

# %%
os.chdir('/content/drive/MyDrive/Books/my-bert-fine-tuned-psh2')

# %%
# !git add *

# %%
# !chmod +x .git/hooks/post-commit
# !chmod +x .git/hooks/pre-push

# %%
# !git commit -m "Initial commit"
# Out:
# [main 9b901c8] Initial commit
#  7 files changed, 64273 insertions(+)
#  create mode 100644 config.json
#  create mode 100644 model.safetensors
#  create mode 100644 special_tokens_map.json
#  create mode 100644 tokenizer.json
#  create mode 100644 tokenizer_config.json
#  create mode 100644 training_args.bin
#  create mode 100644 vocab.txt

# %%
# !git push https://user:{cfg.HF_AUTH}@huggingface.co/{cfg.MY_REPO_NAME2}
# Out:
# Uploading LFS objects: 100% (2/2), 442 MB | 43 MB/s, done.
# Enumerating objects: 10, done.
# Counting objects: 100% (10/10), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (9/9), done.
# Writing objects: 100% (9/9), 351.52 KiB | 3.91 MiB/s, done.
# Total 9 (delta 0), reused 0 (delta 0), pack-reused 0
# To https://huggingface.co/Seonghwan/my-bert-fine-tuned-psh2
#    3fa7c11..9b901c8  main -> main

# %% [markdown]
# #### 모델 불러오기

# %%
tokenizer = AutoTokenizer.from_pretrained('Seonghwan/my-bert-fine-tuned-psh2')
model = AutoModelForSequenceClassification.from_pretrained('Seonghwan/my-bert-fine-tuned-psh2')
# Out:
# tokenizer_config.json:   0%|          | 0.00/1.24k [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/248k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/752k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/995 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/443M [00:00<?, ?B/s]

# %%
print(tokenizer)
print(model)
# Out:
# BertTokenizerFast(name_or_path='Seonghwan/my-bert-fine-tuned-psh2', vocab_size=32000, model_max_length=512, is_fast=True, padding_side='right', truncation_side='right', special_tokens={'unk_token': '[UNK]', 'sep_token': '[SEP]', 'pad_token': '[PAD]', 'cls_token': '[CLS]', 'mask_token': '[MASK]'}, clean_up_tokenization_spaces=True),  added_tokens_decoder={
# 	0: AddedToken("[PAD]", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	1: AddedToken("[UNK]", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	2: AddedToken("[CLS]", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	3: AddedToken("[SEP]", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	4: AddedToken("[MASK]", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# }
# BertForSequenceClassification(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
# ...

# %% [markdown]
# ### huggingface-hub

# %%
# !pip list | grep transformers
# Out:
# transformers                     4.35.2

# %%
# !pip list | grep huggingface-hub
# Out:
# huggingface-hub                  0.19.4

# %%
import os
os.chdir('drive/MyDrive/Books')

# %%
import config as cfg
from transformers import AutoTokenizer, AutoModelForSequenceClassification

# %%
tokenizer = AutoTokenizer.from_pretrained('outputs/trained_model')
model = AutoModelForSequenceClassification.from_pretrained('outputs/trained_model')

# %%
from huggingface_hub import notebook_login

# %%
notebook_login()

# %%
from huggingface_hub import create_repo, delete_repo

# %%
create_repo(cfg.MY_REPO_NAME3)

# %%
delete_repo(cfg.MY_REPO_NAME3)

# %%
from huggingface_hub import Repository

# %%
repo = Repository(cfg.MY_REPO_NAME3.split('/')[1], clone_from=cfg.MY_REPO_NAME3)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_deprecation.py:127: FutureWarning: 'Repository' (from 'huggingface_hub.repository') is deprecated and will be removed from version '1.0'. Please prefer the http-based alternatives instead. Given its large adoption in legacy code, the complete removal is only planned on next major release.
# For more details, please read https://huggingface.co/docs/huggingface_hub/concepts/git_vs_http.
#   warnings.warn(warning_message, FutureWarning)
# /content/drive/MyDrive/Books/my-bert-fine-tuned-psh3 is already a clone of https://huggingface.co/Seonghwan/my-bert-fine-tuned-psh3. Make sure you pull the latest changes with `repo.git_pull()`.
# WARNING:huggingface_hub.repository:/content/drive/MyDrive/Books/my-bert-fine-tuned-psh3 is already a clone of https://huggingface.co/Seonghwan/my-bert-fine-tuned-psh3. Make sure you pull the latest changes with `repo.git_pull()`.

# %%
# !cp -r outputs/trained_model/* {cfg.MY_REPO_NAME3.split('/')[1]}

# %%
repo.git_add()

# %%
repo.git_commit('Initial commit')

# %%
repo.git_push()

# %%
from huggingface_hub import upload_file, delete_file

# %%
upload_file(
    path_or_fileobj=cfg.MY_REPO_NAME3.split('/')[1]+"/vocab.txt",
    path_in_repo="vocab.txt",
    repo_id=cfg.MY_REPO_NAME3,
)
# Out:
# 'https://huggingface.co/Seonghwan/my-bert-fine-tuned-psh3/blob/main/vocab.txt'

# %%
delete_file(
    path_in_repo="config.json",
    repo_id=cfg.MY_REPO_NAME3,
)
# Out:
# CommitInfo(commit_url='https://huggingface.co/Seonghwan/my-bert-fine-tuned-psh3/commit/ceb3a1cb6aea0869a180bad16751da2ab9eb4dcd', commit_message='Delete config.json with huggingface_hub', commit_description='', oid='ceb3a1cb6aea0869a180bad16751da2ab9eb4dcd', pr_url=None, pr_revision=None, pr_num=None)

# %% [markdown]
# #### 모델 불러오기

# %%
tokenizer = AutoTokenizer.from_pretrained('Seonghwan/my-bert-fine-tuned-psh3')
model = AutoModelForSequenceClassification.from_pretrained('Seonghwan/my-bert-fine-tuned-psh3')
# Out:
# tokenizer_config.json:   0%|          | 0.00/1.24k [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/248k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/752k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/995 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/443M [00:00<?, ?B/s]

# %%
print(tokenizer)
# Out:
# BertTokenizerFast(name_or_path='Seonghwan/my-bert-fine-tuned-psh3', vocab_size=32000, model_max_length=512, is_fast=True, padding_side='right', truncation_side='right', special_tokens={'unk_token': '[UNK]', 'sep_token': '[SEP]', 'pad_token': '[PAD]', 'cls_token': '[CLS]', 'mask_token': '[MASK]'}, clean_up_tokenization_spaces=True),  added_tokens_decoder={
# 	0: AddedToken("[PAD]", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	1: AddedToken("[UNK]", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	2: AddedToken("[CLS]", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	3: AddedToken("[SEP]", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	4: AddedToken("[MASK]", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# }

# %%
print(model)
# Out:
# BertForSequenceClassification(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(32000, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
# ...
